# %% [markdown]
# <a href="https://colab.research.google.com/github/juanccq/python-data-science/blob/main/T10_Choque_Quispe_Juan_Carlos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# a. Extraer la información del archivo.

# %%
cvac = pd.read_csv('country_vaccinations.csv',parse_dates=["date"])
cvac.head(5)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/

# %% [markdown]
# b. Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurándote que las columnas con fechas sean del tipo datetime64.

# %%
cvac.dtypes
# Out:
# country                                        object
# iso_code                                       object
# date                                   datetime64[ns]
# total_vaccinations                            float64
# people_vaccinated                             float64
# people_fully_vaccinated                       float64
# daily_vaccinations_raw                        float64
# daily_vaccinations                            float64
# total_vaccinations_per_hundred                float64
# people_vaccinated_per_hundred                 float64
# people_fully_vaccinated_per_hundred           float64
# daily_vaccinations_per_million                float64
# vaccines                                       object
# source_name                                    object
# source_website                                 object
# dtype: object

# %% [markdown]
# c. Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna vaccines, en otras palabras, agrupe por vaccines y realice la sumatoria).

# %%
total_vac = cvac.groupby('vaccines')['total_vaccinations'].sum()
total_vac.head(15)
# Out:
# vaccines
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Soberana02, Sputnik Light, Sputnik V                            1.784348e+08
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                            1.791450e+10
# Abdala, Sinopharm/Beijing, Sinovac, Soberana02, Sputnik Light, Sputnik V                                                      4.228568e+08
# Abdala, Soberana Plus, Soberana02                                                                                             6.405166e+09
# COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/AstraZeneca, Razi Cov Pars, Sinopharm/Beijing, Soberana02, SpikoGen, Sputnik V    1.069480e+10
# CanSino, Covaxin, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V                         1.567789e+10
# CanSino, Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                                    2.851547e+10
# CanSino, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                           1.867895e+10
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac                                                      1.329751e+10
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                                                         1.795720e+10
# CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac, ZF2001                                                                  7.094527e+11
# Covaxin, Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                               2.504773e+07
# Covaxin, Johnson&Johnson, Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac                                                      1.645965e+09
# Covaxin, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V                                  4.234646e+08
# Covaxin, Oxford/AstraZeneca                                                                                                   1.056669e+07
# Name: total_vaccinations, dtype: float64

# %% [markdown]
# d. Obtener la cantidad de vacunas aplicadas en todo el mundo.

# %%
total_mund = cvac['total_vaccinations'].sum()
total_mund
# Out:
# 2002854013761.0

# %% [markdown]
# e. Calcular el promedio de vacunas aplicadas por país.

# %%
prom_pais_vac = cvac.groupby('country')['total_vaccinations'].sum() * 100 / total_mund
prom_pais_vac.head(15)
# para comprobar podemos sumar los valores y obtener 100%
# print(prom_pais_vac.sum())
# Out:
# country
# Afghanistan            0.005894
# Albania                0.014756
# Algeria                0.011930
# Andorra                0.000122
# Angola                 0.019409
# Anguilla               0.000040
# Antigua and Barbuda    0.000342
# Argentina              0.932617
# Armenia                0.001747
# Aruba                  0.001924
# Australia              0.485961
# Austria                0.029795
# Azerbaijan             0.118061
# Bahamas                0.000426
# Bahrain                0.038886
# Name: total_vaccinations, dtype: float64

# %% [markdown]
# f. Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo

# %%
total_290121 = cvac[cvac['date']=='2021-01-29']['total_vaccinations'].sum()
total_290121
# Out:
# 82952931.0

# %% [markdown]
# g. Crear un dataframe nuevo denominado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw.

# %%
conDiferencias = cvac.copy()
conDiferencias['diferencias'] = cvac['daily_vaccinations'] - cvac['daily_vaccinations_raw']
# comprobamos la resta listando las filas que no son nulas
conDiferencias[conDiferencias['daily_vaccinations_raw'].notna()][['daily_vaccinations', 'daily_vaccinations_raw', 'diferencias']].head(15)
# Out:
#      daily_vaccinations  daily_vaccinations_raw  diferencias
# 94               6487.0                  2859.0       3628.0
# 101              5285.0                  4015.0       1270.0
# 339              9802.0                  6868.0       2934.0
# 397                63.0                    60.0          3.0
# 398                66.0                    78.0        -12.0
# 399                62.0                    42.0         20.0
# 400                62.0                    61.0          1.0
# 401                58.0                    36.0         22.0
# 402                55.0                    42.0         13.0
# 403                51.0                    36.0         15.0
# 404                47.0                    36.0         11.0
# 405                40.0                    30.0         10.0
# 433               254.0                  1348.0      -1094.0
# 434               405.0                  1128.0       -723.0
# 466              2895.0                  3461.0       -566.0

# %% [markdown]
# h. Obtener el periodo de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua.

# %%
date_min = cvac['date'].min()
date_max = cvac['date'].max()
print(f"Periodo con mayor tiempo {date_max - date_min}")
# Out:
# Periodo con mayor tiempo 482 days 00:00:00

# %% [markdown]
# i. Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter , ).

# %%
conCantidad = cvac.copy()
conCantidad['canVac'] = conCantidad['vaccines'].str.split(', ').str.len()
conCantidad[["vaccines", "canVac"]].head(10)
# Out:
#                                             vaccines  canVac
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 5  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 6  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 7  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 8  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 9  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4

# %% [markdown]
# j. Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.

# %%
antes20 = cvac[cvac['date'] < '2020-12-20']
antes20.head(15)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 13403   Canada      CAN 2020-12-14                 5.0                5.0
# 13404   Canada      CAN 2020-12-15               727.0              727.0
# 13405   Canada      CAN 2020-12-16              3025.0             3025.0
# 13406   Canada      CAN 2020-12-17              7279.0             7279.0
# 13407   Canada      CAN 2020-12-18             11296.0            11296.0
# 13408   Canada      CAN 2020-12-19             12367.0            12367.0
# 15756    China      CHN 2020-12-15           1500000.0                NaN
# 15757    China      CHN 2020-12-16                 NaN                NaN
# 15758    China      CHN 2020-12-17                 NaN                NaN
# 15759    China      CHN 2020-12-18                 NaN                NaN
# 15760    China      CHN 2020-12-19                 NaN                NaN
# 20826  Denmark      DNK 2020-12-08                 1.0                1.0
# 20827  Denmark      DNK 2020-12-09                 NaN                NaN
# 20828  Denmark      DNK 2020-12-10                 NaN                NaN
# 20829  Denmark      DNK 2020-12-11                 2.0                2.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 13403                      NaN                     NaN                 NaN
# 13404                      NaN                   722.0               722.0
# 13405                      NaN                  2298.0              1510.0
# 13406                      NaN                  4254.0              2425.0
# 13407                      NaN                  4017.0              2823.0
# 13408                      NaN                  1071.0              2472.0
# 15756                      NaN                     NaN                 NaN
# 15757                      NaN                     NaN            187500.0
# 15758                      NaN                     NaN            187500.0
# 15759                      NaN                     NaN            187500.0
# 15760                      NaN                     NaN            187500.0
# 20826                      NaN                     NaN                 NaN
# 20827                      NaN                     NaN                 0.0
# 20828                      NaN                     NaN                 0.0
# 20829                      NaN                     NaN                 0.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 13403                            0.00                           0.00
# 13404                            0.00                           0.00
# 13405                            0.01                           0.01
# 13406                            0.02                           0.02
# 13407                            0.03                           0.03
# 13408                            0.03                           0.03
# 15756                            0.10                            NaN
# 15757                             NaN                            NaN
# 15758                             NaN                            NaN
# 15759                             NaN                            NaN
# 15760                             NaN                            NaN
# 20826                            0.00                           0.00
# 20827                             NaN                            NaN
# 20828                             NaN                            NaN
# 20829                            0.00                           0.00
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 13403                                  NaN                             NaN
# 13404                                  NaN                            19.0
# 13405                                  NaN                            40.0
# 13406                                  NaN                            64.0
# 13407                                  NaN                            74.0
# 13408                                  NaN                            65.0
# 15756                                  NaN                             NaN
# 15757                                  NaN                           130.0
# 15758                                  NaN                           130.0
# 15759                                  NaN                           130.0
# 15760                                  NaN                           130.0
# 20826                                  NaN                             NaN
# 20827                                  NaN                             0.0
# 20828                                  NaN                             0.0
# 20829                                  NaN                             0.0
#
#                                                 vaccines  \
# 13403  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13404  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13405  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13406  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13407  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 13408  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 15756  CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
# 15757  CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
# 15758  CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
# 15759  CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
# 15760  CanSino, Sinopharm/Beijing, Sinopharm/Wuhan, S...
# 20826          Johnson&Johnson, Moderna, Pfizer/BioNTech
# 20827          Johnson&Johnson, Moderna, Pfizer/BioNTech
# 20828          Johnson&Johnson, Moderna, Pfizer/BioNTech
# 20829          Johnson&Johnson, Moderna, Pfizer/BioNTech
#
#                                              source_name  \
# 13403  Official data from provinces via covid19tracke...
# 13404  Official data from provinces via covid19tracke...
# 13405  Official data from provinces via covid19tracke...
# 13406  Official data from provinces via covid19tracke...
# 13407  Official data from provinces via covid19tracke...
# 13408  Official data from provinces via covid19tracke...
# 15756                         National Health Commission
# 15757                         National Health Commission
# 15758                         National Health Commission
# 15759                         National Health Commission
# 15760                         National Health Commission
# 20826                            Statens Serum Institute
# 20827                            Statens Serum Institute
# 20828                            Statens Serum Institute
# 20829                            Statens Serum Institute
#
#                                           source_website
# 13403  https://covid19tracker.ca/vaccinationtracker.html
# 13404  https://covid19tracker.ca/vaccinationtracker.html
# 13405  https://covid19tracker.ca/vaccinationtracker.html
# 13406  https://covid19tracker.ca/vaccinationtracker.html
# 13407  https://covid19tracker.ca/vaccinationtracker.html
# 13408  https://covid19tracker.ca/vaccinationtracker.html
# 15756  http://www.nhc.gov.cn/jkj/s7915/202203/d81d339...
# 15757  http://www.nhc.gov.cn/jkj/s7915/202203/d81d339...
# 15758  http://www.nhc.gov.cn/jkj/s7915/202203/d81d339...
# 15759  http://www.nhc.gov.cn/jkj/s7915/202203/d81d339...
# 15760  http://www.nhc.gov.cn/jkj/s7915/202203/d81d339...
# 20826  https://covid19.ssi.dk/overvagningsdata/downlo...
# 20827  https://covid19.ssi.dk/overvagningsdata/downlo...
# 20828  https://covid19.ssi.dk/overvagningsdata/downlo...
# 20829  https://covid19.ssi.dk/overvagningsdata/downlo...

# %% [markdown]
# k. Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer.

# %%
pfizer = cvac[cvac['vaccines'].str.contains('pfizer', case=False)]
pfizer["vaccines"].head(15)
# Out:
# 0     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 5     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 6     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 7     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 8     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 9     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 10    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 11    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 12    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 13    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 14    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# Name: vaccines, dtype: object

# %% [markdown]
# l. Almacenar los dataframes generados (conDiferencias, conCantidad, antes20 y pfizer) en un archivo de Excel denominado ResultadosTrabajo.xlsx, donde cada dataframe ocupe una hoja diferente

# %%
with pd.ExcelWriter("ResultadosTrabajo.xlsx") as writer:
  conCantidad.to_excel(writer, sheet_name="conCantidad")
  conDiferencias.to_excel(writer, sheet_name="conDiferencias")
  antes20.to_excel(writer, sheet_name="antes20")
  pfizer.to_excel(writer, sheet_name="pfizer")
